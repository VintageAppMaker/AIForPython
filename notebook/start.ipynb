# %% [markdown]
# <a href="https://colab.research.google.com/gist/VintageAppMaker/fce287c4ff3f2dfb6a6af1f306daff0d/start.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # colab을 이용한 python 학습 전에
# > 파이썬과 colab에 대한 기초지식 정리하기
#
# - 문서로 정리
# - 마크다운 이해하기
# - 예제를 문서에서 실행해보기
# - 보관하기

# %%
print ("hello world")
# Out:
# hello world

# %% [markdown]
# ### 1. print 함수
# > 화면에 문자열을 출력하는 함수
#
# ```
# print( 문자열 )
# ```

# %%
print ( 1 + 3)
print ("name" + 3)
print ("name" + " ---> " + "snake")
# Out:
# 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 print ( 1 + 3)
# ----> 2 print ("name" + 3)
#       3 print ("name" + " ---> " + "snake")
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# > 😀 bard에게 물어보기
# ```
# 파이썬에서
# print ("name" + 3)
# 에러 발생이유는?
# ```

# %% [markdown]
# 🤖 bard가 말했다.
#
# ~~~
# print("name" + str(3))
# ~~~

# %%
print ( 1 + 3)
print ("name" + str(3))
print ("name" + " ---> " + "snake")

# %% [markdown]
# ### 2. 들여쓰기, 줄맞추기
# > 파이썬은 들여쓰기가 틀리면 에러이다. 다른 언어에서는 볼 수 없을 정도로 철저하게 지켜진다.

# %%
print ( 1 + 3)
  print ("name" + str(3))
# Out:
#   Cell In[17], line 2
#     print ("name" + str(3))
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# > 😀 위의 코드를 bard, bing, chatGPT에게 프롬프트를 던져본다.
#
# ```
#  print ( 1 + 3)
#   print ("name" + str(3))
#
# 위의 파이썬 코드가 에러나는 이유는?
# ```
#
# 재대로 답변하는 생성 AI는 1군데 밖에 없다.

# %% [markdown]
# ### 3. markdown 이해하기
# > 기술문서의 표준이라 말하는 문법. 상당히 간단함.
#
# - [기술문서 요약](https://namu.wiki/w/%EB%A7%88%ED%81%AC%EB%8B%A4%EC%9A%B4)
# - [온라인에디터 - statckeditor](https://stackedit.io/app#)

# %% [markdown]
# ### 4. 디버깅
# > 값을 디버깅 하는 법(추천안함. 참고사항)
#
# - import pdb
# - pdb.set_trace()
#   - b : 브레이크 포인트
#   - c : run
#   - display : 보기
#
# ```python
# !pip install ipdb
# import ipdb
#
# ipdb.set_trace()
# for i in [1, 2, 3, 4, 5, 6, 7, 8]:
#   print (str(i))
# ```

# %% [markdown]
# 설치는 1번만 하기

# %%
# !pip install ipdb

# %%
import ipdb 

# b 6, i > 5
ipdb.set_trace()  
for i in [1, 2, 3, 4, 5, 6, 7, 8]:
  print (str(i))
