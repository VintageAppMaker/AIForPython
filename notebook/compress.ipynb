# %% [markdown]
# # 파일압축
# > 의사코드로 prompt를 만들고 소스코드를 생성한다.
#
# ChatGPT(🤖)에게 다음과 같이 prompt를 요청했다.
#
# ```python
# 함수: "압축하여 저장하기"
# 이름: def 압축하기()
# 입력받는 값: 압축할경로, 저장할 파일명
# 기능:
#     압축할경로를 base로 그 하위까지 압축하기
#     "파일명.zip"으로 지금소스가 실행되는 폴더에 저장하기
#
# 시작:
#     경로1 = "압축할경로"를 출력하며 입력받기
#     파일1 = "저장할파일"를 출력하며 입력받기
#
#     압축하기(경로1, 파일1)
#
# 파이썬 소스를 만들어줘
# ```
#
# 결과는 다음과 같다.

# %%
import zipfile
import os

def 압축하기(경로, 파일명):
    압축파일 = 파일명 + ".zip"
    with zipfile.ZipFile(압축파일, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for 폴더경로, 하위디렉터리, 파일들 in os.walk(경로):
            for 파일 in 파일들:
                파일경로 = os.path.join(폴더경로, 파일)
                zipf.write(파일경로, os.path.relpath(파일경로, 경로))

if __name__ == "__main__":
    경로1 = input("압축할 경로를 입력하세요: ")
    파일1 = input("저장할 파일명을 입력하세요: ")
    
    압축하기(경로1, 파일1)
# Out:
# 압축할 경로를 입력하세요: ./
# 저장할 파일명을 입력하세요: a

# %% [markdown]
# - Mission
#
# > 미션 1. 확장자가 txt인 파일만 압축하도록 수정하세요. 미션 2. 5분마다 압축하고 시간을 파일명에 넣어주세요
#
# - bard
# - bing
# - ChatGPT

# %% [markdown]
# tip: 미션 1의 프롬프트
#
# ```
# import zipfile
# import os
#
# def 압축하기(경로, 파일명):
#     압축파일 = 파일명 + ".zip"
#     with zipfile.ZipFile(압축파일, 'w', zipfile.ZIP_DEFLATED) as zipf:
#         for 폴더경로, 하위디렉터리, 파일들 in os.walk(경로):
#             for 파일 in 파일들:
#
#                 # [TODO] 아래에 파일의 확장자가 .txt이 아닌 것은
#                 # continue로 처리하여 zipf.write를 실행하지 않게한다.
#                 파일경로 = os.path.join(폴더경로, 파일)
#                 zipf.write(파일경로, os.path.relpath(파일경로, 경로))
#
# if __name__ == "__main__":
#     경로1 = input("압축할 경로를 입력하세요: ")
#     파일1 = input("저장할 파일명을 입력하세요: ")
#
#     압축하기(경로1, 파일1)
#
# [TODO]로 주석처리한 것을 구현해줘
# ````
